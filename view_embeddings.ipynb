# %%
import numpy as np

# 埋め込みファイルのパス
entity_embedding_path = "./output_WN18RR/embedding/entity_embedding.npy"
relation_embedding_path = "./output_WN18RR/embedding/relation_embedding.npy"

# 埋め込みの読み込み
entity_embeddings = np.load(entity_embedding_path)
relation_embeddings = np.load(relation_embedding_path)

# 埋め込みの形状を表示
print("Entity Embeddings Shape:", entity_embeddings.shape)
print("Relation Embeddings Shape:", relation_embeddings.shape)

# 埋め込みの一部を表示
print("\nSample Entity Embedding:", entity_embeddings[0])
print("\nSample Relation Embedding:", relation_embeddings[0])
# Out:
# Entity Embeddings Shape: (40943, 768)
# Relation Embeddings Shape: (11, 768)
#
# Sample Entity Embedding: [-8.10785685e-03  2.22881049e-01 -2.26809368e-01  2.30317146e-01
#  -1.15885891e-01 -2.37567306e-01  8.00009906e-01 -8.55701804e-01
#  -4.74543512e-01 -1.21955954e-01 -1.45613655e-01  1.51693046e-01
#  -8.53507873e-03  1.51283577e-01 -2.10485503e-01  7.07687810e-02
#  -1.10543549e-01 -3.62581275e-02  5.29301465e-02 -1.04871839e-01
#   1.55296758e-01  5.17071337e-02  2.66084801e-02 -1.93950325e-01
#   1.33888081e-01  6.06813952e-02  3.23981866e-02 -3.76968202e-03
#   3.11725467e-01  8.66745338e-02 -1.61913689e-02  6.01490811e-02
#   2.10124090e-01 -2.63282716e-01  1.62025198e-01 -3.28491300e-01
#   1.16197474e-01 -7.28582442e-02  1.07987136e-01 -1.91032201e-01
#   4.45981957e-02  1.87754169e-01  5.73235989e-01 -5.28328121e-01
#   1.34846181e-01 -6.24280982e-02 -4.11966473e-01 -8.36820230e-02
#  -1.67293236e-01 -3.25608365e-02  1.02924190e-01  2.26288185e-01
# ...
